# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook

# %%
url = 'https://www.beeradvocate.com/beer/profile/30356/'
r = requests.get(url)

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
soup.find_all('\/beer\/profile/')
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="Public NoJs uix_javascriptNeedsInit LoggedOut Sidebar Responsive pageIsLtr not_hasTabLinks hasSearch is-sidebarOpen hasRightSidebar is-setWidth navStyle_0 pageStyle_0 hasFlexbox" dir="LTR" id="XenForo" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <base href="https://www.beeradvocate.com/community/"/>
# <script>
# 			var _b = document.getElementsByTagName('base')[0], _bH = "https://www.beeradvocate.com/community/";
# 			if (_b && _b.href != _bH) _b.href = _bH;
# 		</script>
# <title>Prairie Artisan Ales | Tulsa, OK | Beers | BeerAdvocate</title>
# <noscript><style>.JsOnly, .jsOnly { display: none !important; }</style></noscript>
# <link href="css.php?css=xenforo,form,public&amp;style=6&amp;dir=LTR&amp;d=1584233542" rel="stylesheet"/>
# ...

# %%
# this could maybe work, but seems like a blunt way to go about it
# can look for all links, and then just record those with beer/profle/brewery_num/beer_num
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #
# /
# /
# /about/
# /advertise/
# /contact/
# https://www.beeradvocate.com/community/
# https://www.beeradvocate.com/community/
# search/?type=post
# find-new/posts
# /beer/
# /beer/
# /user/beers/
# /forms/add-beer/
# /beer/styles/
# /beer/new/
# /trading/
# /beer/top-rated/
# /beer/top-rated/
# /beer/top-rated/
# /beer/top-rated/us/
# /beer/top-styles/
# /beer/trending/
# /beer/top-new/
# /beer/fame/
# /beer/popular/
# /trading/
# /trading/
# /user/trades/
# /community/#trading.81
# /community/threads/trading-rules-tips.229/
# /community/threads/trading-feedback-system-explained.185895/
# /place/
# /place/
# /user/places/
# /toolbox/add_place/
# /place/directory/
# /place/nearby/
# /community/threads/frequently-asked-questions-faq.444392/
# /community/threads/frequently-asked-questions-faq.444392/
# /about/
# /contact/
# /community/forums/help-resources.32/
# /community/forums/beeradvocate-talk.34/
# /community/threads/how-to-claim-your-place.553982/
# /advertise/
# #
# ...

# %%
<td valign="top" class="hr_bottom_light"><a href="/beer/profile/30356/437787/"><b>A Beer Still Has No Name</b></a></td>

# %%
test = []
for book in soup.find_all('td', attrs={'class':'hr_bottom_light'}):
    test.append(book)

# %%
str_test = []
for book in soup.find_all('td', attrs={'class':'hr_bottom_light'}):
    str_test.append(str(book))

# %%
print(str_test[0][50:76])
print(str_test[0][81:])
# Out:
# /beer/profile/30356/91331/
# 'Merica</b></a></td>

# %%
"""<a href="/beer/profile" """
# Out:
# '<a href="/beer/profile" '

# %%
soup.find_all('table', attrs={'class'}: 'sortable tablesorter tablesorter-default tablesorteraab7bbc5734a3')
# Out:
#   File "<ipython-input-79-5c6e24c186a4>", line 1
#     soup.find_all('table', attrs={'class'}: 'sortable tablesorter tablesorter-default tablesorteraab7bbc5734a3')
#                                           ^
# SyntaxError: invalid syntax

# %%
# just exploring how to explore the three
blah = soup.body
